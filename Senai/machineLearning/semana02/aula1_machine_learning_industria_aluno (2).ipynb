# %% [markdown]
# # Aula 1 – Machine Learning Aplicada à Indústria
# ## Notebook do Aluno
#
# **Nome:** Washington Fernandes de Barros
# **Data:** 05/09/2026
#
# ### Objetivo da aula
# - compreender o problema industrial;
# - ler a base de dados;
# - identificar faltantes, duplicatas e possíveis outliers;
# - registrar observações que serão usadas no pré-processamento.

# %% [markdown]
# ## 1. Importação das bibliotecas
#
# Complete a célula abaixo com as bibliotecas que serão usadas.

# %%
# Complete:
# importar pandas
# importar numpy
# importar matplotlib.pyplot como plt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Leitura da base
#
# Complete com o nome do arquivo e carregue o dataset.

# %%
arquivo='/content/dados_aula1_machine_learning_industria.csv'
df=pd.read_csv(arquivo)

# %% [markdown]
# ## 3. Visualização inicial
#
# Mostre as primeiras linhas da base e registre abaixo o que você percebe.
#
# **Anotações do aluno:**
# - A tabela possui colunas numéricas e categóricas.
# - A tabela possui valores ausentes (NaN).
# - A coluna timestamp indica que os dados são medições feitas de hora em hora, a partir de 10/01/2026.

# %%
# Complete para visualizar as primeiras linhas
df.head()
# Out:
#              timestamp lote_producao operador modo_controle status_valvula  \
# 0  2026-01-10 08:00:00        Lote_A     op_b    automatico         normal
# 1  2026-01-10 09:00:00        Lote_D     op_c       cascata         normal
# 2  2026-01-10 10:00:00        Lote_B     op_d        manual   intermitente
# 3  2026-01-10 11:00:00        Lote_C     op_a    automatico   intermitente
# 4  2026-01-10 12:00:00        Lote_C     op_a    automatico         normal
#
#    setpoint_vazao_l_min  vazao_medida_l_min  pressao_linha_bar  \
# 0                121.44              128.08              3.518
# 1                126.17              119.32              4.616
# 2                128.54              129.11              4.118
# 3                106.50              102.68              3.547
# 4                101.59                 NaN              4.085
#
#    temperatura_processo_c  abertura_valvula_pct  vibracao_bomba_mm_s  \
# 0                   95.00                 56.97                2.960
# 1                   43.34                 63.26                2.532
# 2                   40.67                 63.14                2.182
# 3                   43.94                 64.75                2.772
# 4                  102.00                 83.82                3.173
#
#    tempo_resposta_ms  ph_produto  densidade_produto_g_cm3  \
# 0              220.8        7.09                    1.069
# 1              402.1        6.99                    1.053
# 2              284.1        6.72                    1.021
# 3              486.3        6.67                    1.093
# 4              283.3        6.66                    1.004
#
#   status_instrumentacao
# 0               estavel
# 1              inspecao
# 2              inspecao
# 3              inspecao
# 4               estavel

# %% [markdown]
# ## 4. Tipos de dados
# Verifique os tipos das colunas e descreva quais são numéricas e quais são categóricas.
#
# Anotações do aluno:
#
# **Colunas numéricas:** setpoint_vazao_l_min, vazao_medida_l_min, pressao_linha_bar, temperatura_processo_c, abertura_valvula_pct, vibracao_bomba_mm_s, tempo_resposta_ms, ph_produto, densidade_produto_g_cm3
#
# **Colunas categóricas:** lote_producao, operador, modo_controle, status_valvula, status_instrumentacao
#
# **Coluna data/hora:** timestamp

# %%
print(df.select_dtypes(include=['number']).columns.tolist())
print(df.select_dtypes(include=['object']).columns.tolist())
# Out:
# ['setpoint_vazao_l_min', 'vazao_medida_l_min', 'pressao_linha_bar', 'temperatura_processo_c', 'abertura_valvula_pct', 'vibracao_bomba_mm_s', 'tempo_resposta_ms', 'ph_produto', 'densidade_produto_g_cm3']
# ['timestamp', 'lote_producao', 'operador', 'modo_controle', 'status_valvula', 'status_instrumentacao']

# %%
# Complete para exibir informações gerais da base
print(df.info())
print(df.dtypes)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   timestamp                188 non-null    object
#  1   lote_producao            188 non-null    object
#  2   operador                 183 non-null    object
#  3   modo_controle            183 non-null    object
#  4   status_valvula           188 non-null    object
#  5   setpoint_vazao_l_min     188 non-null    float64
#  6   vazao_medida_l_min       176 non-null    float64
#  7   pressao_linha_bar        178 non-null    float64
#  8   temperatura_processo_c   178 non-null    float64
#  9   abertura_valvula_pct     188 non-null    float64
#  10  vibracao_bomba_mm_s      188 non-null    float64
#  11  tempo_resposta_ms        177 non-null    float64
#  12  ph_produto               180 non-null    float64
#  13  densidade_produto_g_cm3  188 non-null    float64
#  14  status_instrumentacao    188 non-null    object
# dtypes: float64(9), object(6)
# memory usage: 22.2+ KB
# None
# timestamp                   object
# lote_producao               object
# operador                    object
# modo_controle               object
# status_valvula              object
# setpoint_vazao_l_min       float64
# vazao_medida_l_min         float64
# pressao_linha_bar          float64
# temperatura_processo_c     float64
# abertura_valvula_pct       float64
# vibracao_bomba_mm_s        float64
# tempo_resposta_ms          float64
# ph_produto                 float64
# densidade_produto_g_cm3    float64
# status_instrumentacao       object
# dtype: object

# %% [markdown]
# ## 5. Estatísticas descritivas
#
# Gere estatísticas descritivas das variáveis numéricas.

# %%
# Complete
df.describe(include=[np.number]).T
# Out:
#                          count        mean         std      min       25%  \
# setpoint_vazao_l_min     188.0  119.056277   12.164116   90.340  110.3375
# vazao_medida_l_min       176.0  119.571761   13.808622   90.230  110.2875
# pressao_linha_bar        178.0    3.954781    0.842332    2.811    3.5655
# temperatura_processo_c   178.0   43.874213    9.399248   26.070   40.0275
# abertura_valvula_pct     188.0   58.468617   16.380992   18.010   46.7575
# vibracao_bomba_mm_s      188.0    2.336059    0.958364    0.386    1.7935
# tempo_resposta_ms        177.0  337.286441  129.197193  130.100  278.2000
# ph_produto               180.0    6.806500    0.312416    6.040    6.6100
# densidade_produto_g_cm3  188.0    1.040255    0.030946    0.949    1.0210
#
#                               50%       75%       max
# setpoint_vazao_l_min     119.2300  126.9200   156.950
# vazao_medida_l_min       118.5650  128.7800   160.330
# pressao_linha_bar          3.8865    4.1190    10.200
# temperatura_processo_c    43.1750   46.6650   110.000
# abertura_valvula_pct      58.6000   67.7500    99.280
# vibracao_bomba_mm_s        2.2900    2.7210     9.100
# tempo_resposta_ms        321.4000  377.5000  1500.000
# ph_produto                 6.8200    7.0125     7.560
# densidade_produto_g_cm3    1.0395    1.0620     1.134

# %% [markdown]
# ## 6. Valores faltantes
#
# Descubra quantos valores faltantes existem por coluna.
#
# **Pergunta:** quais colunas parecem exigir maior atenção?

# %%
# Complete
df.isna().sum().sort_values(ascending=False)
# Out:
# vazao_medida_l_min         12
# tempo_resposta_ms          11
# pressao_linha_bar          10
# temperatura_processo_c     10
# ph_produto                  8
# modo_controle               5
# operador                    5
# setpoint_vazao_l_min        0
# status_valvula              0
# timestamp                   0
# lote_producao               0
# vibracao_bomba_mm_s         0
# abertura_valvula_pct        0
# densidade_produto_g_cm3     0
# status_instrumentacao       0
# dtype: int64

# %% [markdown]
# **Resposta do aluno:**
#
# As colunas que mais exigem atenção são as variáveis numéricas de processo: `vazao_medida_l_min`, `tempo_resposta_ms`, `pressao_linha_bar` e `temperatura_processo_c`, pois apresentam entre 5% e 6,4% de valores ausentes e são fundamentais para monitoramento e para qualquer modelo preditivo. Em especial, `vazao_medida_l_min` merece destaque por ser a medição correspondente ao setpoint de vazão.

# %% [markdown]
# ## 7. Duplicatas
#
# Verifique se existem linhas duplicadas.

# %%
df[df.duplicated]
# Out:
#                timestamp lote_producao operador modo_controle status_valvula  \
# 180  2026-01-16 02:00:00        Lote_A     op_b    automatico         normal
# 181  2026-01-11 20:00:00        Lote_B     op_b    automatico         normal
# 182  2026-01-17 09:00:00        Lote_A     op_a    automatico         normal
# 183  2026-01-16 07:00:00        Lote_A     op_b    automatico         normal
# 184  2026-01-15 14:00:00        Lote_B     op_b        manual         normal
# 185  2026-01-15 21:00:00        Lote_B     op_c    automatico        travada
# 186  2026-01-14 14:00:00        Lote_A     op_b    automatico         normal
# 187  2026-01-11 16:00:00        Lote_A     op_b    automatico         normal
#
#      setpoint_vazao_l_min  vazao_medida_l_min  pressao_linha_bar  \
# 180                126.92              127.07              3.188
# 181                104.35              117.10              3.604
# 182                129.25              130.73              4.119
# 183                118.13              110.30              3.899
# 184                112.18              111.88              4.422
# 185                106.44               92.76              3.623
# 186                123.25              120.36              3.720
# 187                124.61              118.29              4.222
#
#      temperatura_processo_c  abertura_valvula_pct  vibracao_bomba_mm_s  \
# 180                   47.67                 56.22                1.830
# 181                   41.98                 74.36                2.865
# 182                   41.68                 53.36                2.494
# 183                   41.80                 67.75                3.392
# 184                   47.48                 77.64                2.083
# 185                   40.08                 59.22                3.021
# 186                     NaN                 49.08                3.130
# 187                   46.32                 18.01                2.312
#
#      tempo_resposta_ms  ph_produto  densidade_produto_g_cm3  \
# 180                NaN        6.89                    1.062
# 181                NaN        6.94                    1.039
# 182              405.6        6.84                    0.980
# 183              265.0         NaN                    1.063
# 184              308.3        6.87                    1.039
# 185              226.5        6.78                    0.999
# 186              250.3        6.82                    0.987
# 187              399.4        6.92                    1.069
#
#     status_instrumentacao
# 180               estavel
# 181              inspecao
# 182               estavel
# 183               estavel
# 184               estavel
# 185              inspecao
# 186               estavel
# 187               estavel

# %% [markdown]
# **Resposta do aluno:**
# Quantidade de duplicatas encontradas: Oito duplicatas.

# %%
# Complete
df.drop_duplicates()
# Out:
#                timestamp lote_producao operador modo_controle status_valvula  \
# 0    2026-01-10 08:00:00        Lote_A     op_b    automatico         normal
# 1    2026-01-10 09:00:00        Lote_D     op_c       cascata         normal
# 2    2026-01-10 10:00:00        Lote_B     op_d        manual   intermitente
# 3    2026-01-10 11:00:00        Lote_C     op_a    automatico   intermitente
# 4    2026-01-10 12:00:00        Lote_C     op_a    automatico         normal
# ..                   ...           ...      ...           ...            ...
# 175  2026-01-17 15:00:00        Lote_A     op_d    automatico         normal
# 176  2026-01-17 16:00:00        Lote_B     op_b        manual         normal
# 177  2026-01-17 17:00:00        Lote_A     op_d    automatico         normal
# 178  2026-01-17 18:00:00        Lote_B     op_c       cascata        travada
# 179  2026-01-17 19:00:00        Lote_A     op_c    automatico         normal
#
#      setpoint_vazao_l_min  vazao_medida_l_min  pressao_linha_bar  \
# 0                  121.44              128.08              3.518
# 1                  126.17              119.32              4.616
# 2                  128.54              129.11              4.118
# 3                  106.50              102.68              3.547
# 4                  101.59                 NaN              4.085
# ..                    ...                 ...                ...
# 175                147.25              146.48              3.755
# 176                122.18              131.37              4.631
# 177                122.98              117.35              3.318
# 178                114.49              114.21              3.114
# 179                109.80              123.97              3.489
#
#      temperatura_processo_c  abertura_valvula_pct  vibracao_bomba_mm_s  \
# 0                     95.00                 56.97                2.960
# 1                     43.34                 63.26                2.532
# 2                     40.67                 63.14                2.182
# 3                     43.94                 64.75                2.772
# 4                    102.00                 83.82                3.173
# ..                      ...                   ...                  ...
# 175                   35.71                 45.91                1.920
# 176                   50.98                 66.58                2.357
# 177                   35.70                 43.62                2.853
# 178                   43.66                 58.45                1.207
# 179                   37.85                 57.85                0.967
#
#      tempo_resposta_ms  ph_produto  densidade_produto_g_cm3  \
# 0                220.8        7.09                    1.069
# 1                402.1        6.99                    1.053
# 2                284.1        6.72                    1.021
# 3                486.3        6.67                    1.093
# 4                283.3        6.66                    1.004
# ..                 ...         ...                      ...
# 175              280.5        6.83                    1.001
# 176              404.3        6.86                    0.949
# 177              318.5        6.44                    1.046
# 178              255.0        7.24                    1.094
# 179              287.2        6.50                    1.077
#
#     status_instrumentacao
# 0                 estavel
# 1                inspecao
# 2                inspecao
# 3                inspecao
# 4                 estavel
# ..                    ...
# 175               estavel
# 176              inspecao
# 177               estavel
# 178              inspecao
# 179              inspecao
#
# [180 rows x 15 columns]

# %% [markdown]
# ## 8. Busca inicial por outliers
#
# Escolha algumas colunas numéricas importantes e gere boxplots.
# Sugestão:
# - pressao_linha_bar
# - temperatura_processo_c
# - vibracao_bomba_mm_s
# - tempo_resposta_ms

# %%
# Complete
# dica: crie uma lista com as colunas e use um laço para gerar os gráficos

lista_colunas=df.select_dtypes(include=['number']).columns.tolist()

for coluna in lista_colunas:
    plt.figure(figsize=(10,8))

    plt.boxplot(df[coluna].dropna(),vert=False)
    plt.title(f'Boxplot - {coluna}')
    plt.xlabel(coluna)
    plt.show()

# %% [markdown]
# **Anotações do aluno sobre possíveis outliers:**
#
# - As variáveis **temperatura_processo_c** (6 outliers) e **tempo_resposta_ms** (4 outliers) foram as que apresentaram mais valores discrepantes, com temperatura chegando a 95–110°C (bem acima da faixa normal de ~29–57°C) e tempo de resposta chegando a 1200–1500 ms (faixa normal ~135–522 ms) — possíveis falhas de sensor ou eventos reais de anomalia no processo.
# - **pressao_linha_bar** (3 outliers, valores de 8,9 a 10,2 bar) e **vibracao_bomba_mm_s** (2 outliers, valores de 8,5 e 9,1 mm/s) também mostraram pontos bem acima da faixa esperada, o que pode indicar problemas mecânicos ou de instrumentação na bomba/linha.
# - As demais colunas (setpoint_vazao_l_min, vazao_medida_l_min, abertura_valvula_pct, densidade_produto_g_cm3) tiveram poucos outliers (1 a 3 cada) e de menor magnitude, enquanto **ph_produto** não apresentou nenhum outlier pela regra do IQR — sendo a variável mais "limpa" da base.

# %% [markdown]
# ## 9. Correlação entre variáveis numéricas
#
# Calcule a matriz de correlação.

# %%
# Complete
correlation_matrix=df.select_dtypes(include=['number']).corr()
correlation_matrix
# Out:
#                          setpoint_vazao_l_min  vazao_medida_l_min  \
# setpoint_vazao_l_min                 1.000000            0.801101
# vazao_medida_l_min                   0.801101            1.000000
# pressao_linha_bar                   -0.091657            0.012123
# temperatura_processo_c               0.017862            0.089933
# abertura_valvula_pct                 0.054249            0.068041
# vibracao_bomba_mm_s                 -0.131508           -0.070068
# tempo_resposta_ms                    0.043946           -0.036759
# ph_produto                           0.159991            0.133953
# densidade_produto_g_cm3             -0.031027           -0.072082
#
#                          pressao_linha_bar  temperatura_processo_c  \
# setpoint_vazao_l_min             -0.091657                0.017862
# vazao_medida_l_min                0.012123                0.089933
# pressao_linha_bar                 1.000000               -0.040471
# temperatura_processo_c           -0.040471                1.000000
# abertura_valvula_pct             -0.031933               -0.002120
# vibracao_bomba_mm_s              -0.004311                0.057550
# tempo_resposta_ms                -0.034882               -0.016420
# ph_produto                       -0.033072                0.021347
# densidade_produto_g_cm3           0.071375               -0.024445
#
#                          abertura_valvula_pct  vibracao_bomba_mm_s  \
# setpoint_vazao_l_min                 0.054249            -0.131508
# vazao_medida_l_min                   0.068041            -0.070068
# pressao_linha_bar                   -0.031933            -0.004311
# temperatura_processo_c              -0.002120             0.057550
# abertura_valvula_pct                 1.000000            -0.093294
# vibracao_bomba_mm_s                 -0.093294             1.000000
# tempo_resposta_ms                   -0.025390            -0.064778
# ph_produto                          -0.005975            -0.078114
# densidade_produto_g_cm3             -0.054070            -0.101135
#
#                          tempo_resposta_ms  ph_produto  \
# setpoint_vazao_l_min              0.043946    0.159991
# vazao_medida_l_min               -0.036759    0.133953
# pressao_linha_bar                -0.034882   -0.033072
# temperatura_processo_c           -0.016420    0.021347
# abertura_valvula_pct             -0.025390   -0.005975
# vibracao_bomba_mm_s              -0.064778   -0.078114
# tempo_resposta_ms                 1.000000    0.097510
# ph_produto                        0.097510    1.000000
# densidade_produto_g_cm3           0.027675    0.001702
#
#                          densidade_produto_g_cm3
# setpoint_vazao_l_min                   -0.031027
# vazao_medida_l_min                     -0.072082
# pressao_linha_bar                       0.071375
# temperatura_processo_c                 -0.024445
# abertura_valvula_pct                   -0.054070
# vibracao_bomba_mm_s                    -0.101135
# tempo_resposta_ms                       0.027675
# ph_produto                              0.001702
# densidade_produto_g_cm3                 1.000000

# %%
# Mapa de calor

plt.figure(figsize=(10,6))
plt.imshow(correlation_matrix,aspect='auto')
plt.colorbar()
plt.title('Correlação entre variáveis numéricas')
plt.show()

# %% [markdown]
# ## 10. Criação de uma variável auxiliar
#
# Crie uma variável com o desvio absoluto entre:
# - setpoint_vazao_l_min
# - vazao_medida_l_min
#
# Nome sugerido: `desvio_vazao_abs`

# %%
# Criando uma variável auxiliar

df['desvio_vazao_abs']=(df['setpoint_vazao_l_min']-df['vazao_medida_l_min']).abs()

df[['setpoint_vazao_l_min','vazao_medida_l_min','desvio_vazao_abs']]
# Out:
#      setpoint_vazao_l_min  vazao_medida_l_min  desvio_vazao_abs
# 0                  121.44              128.08              6.64
# 1                  126.17              119.32              6.85
# 2                  128.54              129.11              0.57
# 3                  106.50              102.68              3.82
# 4                  101.59                 NaN               NaN
# ..                    ...                 ...               ...
# 183                118.13              110.30              7.83
# 184                112.18              111.88              0.30
# 185                106.44               92.76             13.68
# 186                123.25              120.36              2.89
# 187                124.61              118.29              6.32
#
# [188 rows x 3 columns]

# %%
#Atividade de fechamento

resumo = {
    'linhas': df.shape[0],
    'colunas': df.shape[1],
    'duplicatas': int(df.duplicated().sum()),
    'colunas_com_faltantes': int((df.isna().sum() > 0).sum())
}

print('Resumo dos dados ')
for chave,valor in resumo.items():
  print(f'{chave}:{valor}')
# Out:
# Resumo dos dados
# linhas:188
# colunas:16
# duplicatas:8
# colunas_com_faltantes:8

# %% [markdown]
# ## 11. Interpretação técnica
#
# Responda com base na exploração realizada:
#
# **1. Quais problemas de qualidade de dados foram identificados?**
#
# Dados ausentes, valores duplicados e outliers.
#
# **2. Quais variáveis parecem críticas para avaliar a instrumentação?**
#
# vazao_medida_l_min; tempo_resposta_ms; pressao_linha_bar; temperatura_processo_c.
#
# Essas são variáveis de medição direta do processo (não são parâmetros configuráveis como o setpoint), então concentraram a maior parte dos valores ausentes e dos outliers detectados — problemas nelas costumam refletir falhas reais de sensores ou da instrumentação.
#
# **3. Por que não devemos treinar um modelo imediatamente, sem inspeção?**
#
# Dados ausentes podem gerar erros no treinamento ou viés se tratados sem critério; duplicatas fazem o modelo "aprender" o mesmo caso mais de uma vez, distorcendo padrões; e outliers podem distorcer estatísticas (média, desvio padrão) e o ajuste do modelo, levando-o a dar peso excessivo a casos raros/anômalos em vez do comportamento normal do processo.

# %% [markdown]
# ## 12. Fechamento
#
# Nesta aula, você começou a trabalhar o início do pipeline de Machine Learning:
# - definição do problema;
# - conhecimento da base;
# - análise exploratória;
# - identificação de problemas de qualidade.
#
# Na próxima etapa, a base poderá ser tratada para uso em modelagem.

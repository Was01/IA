# %% [markdown]
# # Aula 3 — Preparação final da base para modelagem
#
# ## Contexto
# Nesta aula, continuaremos o projeto de **Machine Learning Aplicada à Indústria**, utilizando a base de dados de uma planta química com foco no monitoramento do **status da instrumentação** de um sistema de controle de vazão de produtos químicos.
#
# ## Foco da aula
# - normalização e padronização
# - codificação de variáveis categóricas
# - preparação final da base para modelagem
#
# ## Resultado esperado
# Ao final da aula, a turma deverá gerar uma base pronta para modelagem, com variáveis numéricas escaladas, variáveis categóricas codificadas e separação entre atributos preditores e variável-alvo.

# %% [markdown]
# ## Orientações ao aluno
# Complete as células indicadas com base na demonstração guiada do professor.
# Registre observações técnicas sempre que solicitado.

# %%
#importar pandas
#importar numpy
#importar MinMaxScaler e StandardScaler(de sklearn.preprocessing )

import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %% [markdown]
# ## 1. Carregamento da base
#
# Tente carregar primeiro a base tratada da aula anterior.
# Se necessário, utilize a base bruta para fins de prática.

# %%
# Complete o nome do arquivo tratado, se necessário
arquivo_tratado = '/content/dados_aula2_tratados.csv'
arquivo_bruto = '/content/dados_aula1_machine_learning_industria.csv'

try:
    df = pd.read_csv(arquivo_tratado)
    print(f'Base carregada: {arquivo_tratado}')
except:
    df = pd.read_csv(arquivo_bruto)
    print('Base bruta carregada para fins didáticos.')

df.head()
# Out:
# Base carregada: /content/dados_aula2_tratados.csv
#              timestamp lote_producao operador modo_controle status_valvula  \
# 0  2026-01-10 08:00:00        Lote_A     op_b    automatico         normal
# 1  2026-01-10 09:00:00        Lote_D     op_c       cascata         normal
# 2  2026-01-10 10:00:00        Lote_B     op_d        manual   intermitente
# 3  2026-01-10 11:00:00        Lote_C     op_a    automatico   intermitente
# 4  2026-01-10 12:00:00        Lote_C     op_a    automatico         normal
#
#    setpoint_vazao_l_min  vazao_medida_l_min  pressao_linha_bar  \
# 0                121.44             128.080              3.518
# 1                126.17             119.320              4.616
# 2                128.54             129.110              4.118
# 3                106.50             102.680              3.547
# 4                101.59             118.565              4.085
#
#    temperatura_processo_c  abertura_valvula_pct  vibracao_bomba_mm_s  \
# 0                55.55625                 56.97                2.960
# 1                43.34000                 63.26                2.532
# 2                40.67000                 63.14                2.182
# 3                43.94000                 64.75                2.772
# 4                55.55625                 83.82                3.173
#
#    tempo_resposta_ms  ph_produto  densidade_produto_g_cm3  \
# 0              220.8        7.09                    1.069
# 1              402.1        6.99                    1.053
# 2              284.1        6.72                    1.021
# 3              486.3        6.67                    1.093
# 4              283.3        6.66                    1.004
#
#   status_instrumentacao
# 0               estavel
# 1              inspecao
# 2              inspecao
# 3              inspecao
# 4               estavel

# %% [markdown]
# ## 2. Inspeção inicial da base
#
# Preencha os comandos para visualizar:
# - dimensão da base;
# - tipos de dados;
# - nomes das colunas.

# %%
# Exiba a dimensão da base
print('Dimensão da base:', df.shape)

# Exiba os tipos de dados
display(df.dtypes)

# Exiba os nomes das colunas
display(pd.DataFrame({'coluna': df.columns}))
# Out:
# Dimensão da base: (180, 15)
# timestamp                   object
# lote_producao               object
# operador                    object
# modo_controle               object
# status_valvula              object
# setpoint_vazao_l_min       float64
# vazao_medida_l_min         float64
# pressao_linha_bar          float64
# temperatura_processo_c     float64
# abertura_valvula_pct       float64
# vibracao_bomba_mm_s        float64
# tempo_resposta_ms          float64
# ph_produto                 float64
# densidade_produto_g_cm3    float64
# status_instrumentacao       object
# dtype: object
#                      coluna
# 0                 timestamp
# 1             lote_producao
# 2                  operador
# 3             modo_controle
# 4            status_valvula
# 5      setpoint_vazao_l_min
# 6        vazao_medida_l_min
# 7         pressao_linha_bar
# 8    temperatura_processo_c
# 9      abertura_valvula_pct
# 10      vibracao_bomba_mm_s
# 11        tempo_resposta_ms
# 12               ph_produto
# 13  densidade_produto_g_cm3
# 14    status_instrumentacao

# %% [markdown]
# ## 3. Identificação de colunas numéricas e categóricas

# %%
colunas_numericas = df.select_dtypes(include='number').columns.tolist()
colunas_categoricas = df.select_dtypes(include=['object', 'category']).columns.tolist()

print('Colunas numéricas:', colunas_numericas)
print('\nColunas categóricas:', colunas_categoricas)
# Out:
# Colunas numéricas: ['setpoint_vazao_l_min', 'vazao_medida_l_min', 'pressao_linha_bar', 'temperatura_processo_c', 'abertura_valvula_pct', 'vibracao_bomba_mm_s', 'tempo_resposta_ms', 'ph_produto', 'densidade_produto_g_cm3']
#
# Colunas categóricas: ['timestamp', 'lote_producao', 'operador', 'modo_controle', 'status_valvula', 'status_instrumentacao']

# %% [markdown]
# **Registro do aluno:**
# Quais colunas parecem mais importantes para o problema industrial?
# - Resposta: status_valvula, vazao_medida_l_min, setpoint_vazao_l_min,
# abertura_valvula_pct, tempo_resposta_ms, vibracao_bomba_mm_s.

# %% [markdown]
# ## 4. Separação da variável-alvo
#
# Utilize como variável-alvo a coluna `status_instrumentacao`.

# %%
alvo = 'status_instrumentacao'

X = df.drop(columns=[alvo]).copy()
y = df[alvo].copy()

print('Dimensão de X:', X.shape)
print('Dimensão de y:', y.shape)
display(y.value_counts(dropna=False).rename_axis('classe').reset_index(name='quantidade'))
# Out:
# Dimensão de X: (180, 14)
# Dimensão de y: (180,)
#      classe  quantidade
# 0  inspecao         116
# 1   estavel          64

# %% [markdown]
# ## 5. Separação entre dados numéricos e categóricos

# %%
X_numerico = X.select_dtypes(include='number').copy()
X_categorico = X.select_dtypes(include=['object', 'category']).copy()

display(X_numerico.head())
display(X_categorico.head())
# Out:
#    setpoint_vazao_l_min  vazao_medida_l_min  pressao_linha_bar  \
# 0                121.44             128.080              3.518
# 1                126.17             119.320              4.616
# 2                128.54             129.110              4.118
# 3                106.50             102.680              3.547
# 4                101.59             118.565              4.085
#
#    temperatura_processo_c  abertura_valvula_pct  vibracao_bomba_mm_s  \
# 0                55.55625                 56.97                2.960
# 1                43.34000                 63.26                2.532
# 2                40.67000                 63.14                2.182
# 3                43.94000                 64.75                2.772
# 4                55.55625                 83.82                3.173
#
#    tempo_resposta_ms  ph_produto  densidade_produto_g_cm3
# 0              220.8        7.09                    1.069
# 1              402.1        6.99                    1.053
# 2              284.1        6.72                    1.021
# 3              486.3        6.67                    1.093
# 4              283.3        6.66                    1.004
#              timestamp lote_producao operador modo_controle status_valvula
# 0  2026-01-10 08:00:00        Lote_A     op_b    automatico         normal
# 1  2026-01-10 09:00:00        Lote_D     op_c       cascata         normal
# 2  2026-01-10 10:00:00        Lote_B     op_d        manual   intermitente
# 3  2026-01-10 11:00:00        Lote_C     op_a    automatico   intermitente
# 4  2026-01-10 12:00:00        Lote_C     op_a    automatico         normal

# %% [markdown]
# ## 6. Normalização
#
# Complete o código para aplicar `MinMaxScaler` nas variáveis numéricas.

# %%
scaler_minmax = MinMaxScaler()

X_normalizado_array = scaler_minmax.fit_transform(X_numerico)

X_normalizado = pd.DataFrame(
    X_normalizado_array,
    columns=X_numerico.columns,
    index=X_numerico.index
)

X_normalizado.head()
# Out:
#    setpoint_vazao_l_min  vazao_medida_l_min  pressao_linha_bar  \
# 0              0.466897            0.578050           0.335708
# 1              0.537907            0.444266           0.857075
# 2              0.573487            0.593780           0.620608
# 3              0.242606            0.190138           0.349478
# 4              0.168894            0.432736           0.604938
#
#    temperatura_processo_c  abertura_valvula_pct  vibracao_bomba_mm_s  \
# 0                1.000000              0.479390             0.691935
# 1                0.507211              0.556786             0.576882
# 2                0.399506              0.555309             0.482796
# 3                0.531414              0.575120             0.641398
# 4                1.000000              0.809770             0.749194
#
#    tempo_resposta_ms  ph_produto  densidade_produto_g_cm3
# 0           0.197053    0.690789                 0.648649
# 1           0.708333    0.625000                 0.562162
# 2           0.375564    0.447368                 0.389189
# 3           0.945784    0.414474                 0.778378
# 4           0.373308    0.407895                 0.297297

# %% [markdown]
# ## 7. Comparação antes e depois da normalização

# %%
comparacao_normalizacao = pd.DataFrame({
    'valor_original_min': X_numerico.min(),
    'valor_original_max': X_numerico.max(),
    'valor_normalizado_min': X_normalizado.min(),
    'valor_normalizado_max': X_normalizado.max()
})

display(comparacao_normalizacao)
# Out:
#                          valor_original_min  valor_original_max  \
# setpoint_vazao_l_min               90.34000           156.95000
# vazao_medida_l_min                 90.23000           155.70875
# pressao_linha_bar                   2.81100             4.91700
# temperatura_processo_c             30.76625            55.55625
# abertura_valvula_pct               18.01000            99.28000
# vibracao_bomba_mm_s                 0.38600             4.10600
# tempo_resposta_ms                 150.92500           505.52500
# ph_produto                          6.04000             7.56000
# densidade_produto_g_cm3             0.94900             1.13400
#
#                          valor_normalizado_min  valor_normalizado_max
# setpoint_vazao_l_min                       0.0                    1.0
# vazao_medida_l_min                         0.0                    1.0
# pressao_linha_bar                          0.0                    1.0
# temperatura_processo_c                     0.0                    1.0
# abertura_valvula_pct                       0.0                    1.0
# vibracao_bomba_mm_s                        0.0                    1.0
# tempo_resposta_ms                          0.0                    1.0
# ph_produto                                 0.0                    1.0
# densidade_produto_g_cm3                    0.0                    1.0

# %% [markdown]
# **Registro do aluno:**
# O que mudou nos dados após a normalização?
# Após a normalização, todos os valores numéricos foram reescalados para o intervalo [0, 1]

# %% [markdown]
# ## 8. Padronização
#
# Agora aplique `StandardScaler` às variáveis numéricas.

# %%
scaler_standard = StandardScaler()

X_padronizado_array = scaler_standard.fit_transform(X_numerico)

X_padronizado = pd.DataFrame(
    X_padronizado_array,
    columns=X_numerico.columns,
    index=X_numerico.index
)

X_padronizado.head()
# Out:
#    setpoint_vazao_l_min  vazao_medida_l_min  pressao_linha_bar  \
# 0              0.191198            0.639145          -0.856294
# 1              0.577176           -0.021791           1.750977
# 2              0.770573            0.716858           0.568444
# 3             -1.027936           -1.277268          -0.787432
# 4             -1.428602           -0.078755           0.490084
#
#    temperatura_processo_c  abertura_valvula_pct  vibracao_bomba_mm_s  \
# 0                2.317030             -0.096176             0.971771
# 1                0.040508              0.290154             0.368680
# 2               -0.457051              0.282783            -0.124501
# 3                0.152319              0.381669             0.706862
# 4                2.317030              1.552943             1.271907
#
#    tempo_resposta_ms  ph_produto  densidade_produto_g_cm3
# 0          -1.574939    0.916810                 0.922717
# 1           1.087681    0.595436                 0.400630
# 2          -0.645298   -0.272276                -0.643545
# 3           2.324265   -0.432963                 1.705849
# 4          -0.657047   -0.465100                -1.198264

# %% [markdown]
# ## 9. Comparação antes e depois da padronização

# %%
comparacao_padronizacao = pd.DataFrame({
    'media_original': X_numerico.mean(),
    'desvio_original': X_numerico.std(),
    'media_padronizada': X_padronizado.mean(),
    'desvio_padronizado': X_padronizado.std()
})

display(comparacao_padronizacao.round(4))
# Out:
#                          media_original  desvio_original  media_padronizada  \
# setpoint_vazao_l_min           119.0969          12.2888               -0.0
# vazao_medida_l_min             119.6088          13.2909                0.0
# pressao_linha_bar                3.8786           0.4223                0.0
# temperatura_processo_c          43.1226           5.3812                0.0
# abertura_valvula_pct            58.5359          16.3268                0.0
# vibracao_bomba_mm_s              2.2704           0.7117               -0.0
# tempo_resposta_ms              328.0389          68.2808               -0.0
# ph_produto                       6.8047           0.3120               -0.0
# densidade_produto_g_cm3          1.0407           0.0307                0.0
#
#                          desvio_padronizado
# setpoint_vazao_l_min                 1.0028
# vazao_medida_l_min                   1.0028
# pressao_linha_bar                    1.0028
# temperatura_processo_c               1.0028
# abertura_valvula_pct                 1.0028
# vibracao_bomba_mm_s                  1.0028
# tempo_resposta_ms                    1.0028
# ph_produto                           1.0028
# densidade_produto_g_cm3              1.0028

# %% [markdown]
# **Registro do aluno:**
# Quando a padronização pode ser mais útil que a normalização?
# A padronização costuma ser mais útil que a normalização quando:
#
# Há outliers nos dados: a padronização é menos sensível a valores extremos, pois usa média e desvio padrão, enquanto o MinMax se baseia em mínimo/máximo — um único outlier distorce toda a escala.
# Os dados seguem (ou se aproximam de) uma distribuição normal: a padronização preserva melhor essa forma, centralizando em 0 com desvio padrão 1.
# O algoritmo assume dados centrados em zero: como regressão linear/logística com regularização (Ridge, Lasso), SVM, PCA e redes neurais — esses métodos tendem a performar melhor com dados padronizados.
# Não se sabe o intervalo fixo dos dados futuros: a normalização fixa um intervalo [0,1] baseado no min/max do conjunto de treino, o que pode ser problemático se novos dados ultrapassarem esses limites.

# %% [markdown]
# ## 10. Codificação de variáveis categóricas
#
# Utilize `pd.get_dummies()` para transformar as variáveis categóricas em colunas numéricas.

# %%
X_categorico_codificado = pd.get_dummies(X_categorico, drop_first=False)

print('Dimensão da base categórica codificada:', X_categorico_codificado.shape)
X_categorico_codificado.head()
# Out:
# Dimensão da base categórica codificada: (180, 194)
#    timestamp_2026-01-10 08:00:00  timestamp_2026-01-10 09:00:00  \
# 0                           True                          False
# 1                          False                           True
# 2                          False                          False
# 3                          False                          False
# 4                          False                          False
#
#    timestamp_2026-01-10 10:00:00  timestamp_2026-01-10 11:00:00  \
# 0                          False                          False
# 1                          False                          False
# 2                           True                          False
# 3                          False                           True
# 4                          False                          False
#
#    timestamp_2026-01-10 12:00:00  timestamp_2026-01-10 13:00:00  \
# 0                          False                          False
# 1                          False                          False
# 2                          False                          False
# 3                          False                          False
# 4                           True                          False
#
#    timestamp_2026-01-10 14:00:00  timestamp_2026-01-10 15:00:00  \
# 0                          False                          False
# 1                          False                          False
# 2                          False                          False
# 3                          False                          False
# 4                          False                          False
#
#    timestamp_2026-01-10 16:00:00  timestamp_2026-01-10 17:00:00  ...  \
# 0                          False                          False  ...
# 1                          False                          False  ...
# 2                          False                          False  ...
# 3                          False                          False  ...
# 4                          False                          False  ...
#
#    operador_op_a  operador_op_b  operador_op_c  operador_op_d  \
# 0          False           True          False          False
# 1          False          False           True          False
# 2          False          False          False           True
# 3           True          False          False          False
# 4           True          False          False          False
#
#    modo_controle_automatico  modo_controle_cascata  modo_controle_manual  \
# 0                      True                  False                 False
# 1                     False                   True                 False
# 2                     False                  False                  True
# 3                      True                  False                 False
# 4                      True                  False                 False
#
#    status_valvula_intermitente  status_valvula_normal  status_valvula_travada
# 0                        False                   True                   False
# 1                        False                   True                   False
# 2                         True                  False                   False
# 3                         True                  False                   False
# 4                        False                   True                   False
#
# [5 rows x 194 columns]

# %% [markdown]
# ## 11. Preparação da base final para modelagem
#
# Monte a base final usando:
# - variáveis numéricas padronizadas;
# - variáveis categóricas codificadas.

# %%
X_final = pd.concat([X_padronizado, X_categorico_codificado], axis=1)

print('Dimensão da base final de atributos:', X_final.shape)
display(X_final.head())
# Out:
# Dimensão da base final de atributos: (180, 203)
#    setpoint_vazao_l_min  vazao_medida_l_min  pressao_linha_bar  \
# 0              0.191198            0.639145          -0.856294
# 1              0.577176           -0.021791           1.750977
# 2              0.770573            0.716858           0.568444
# 3             -1.027936           -1.277268          -0.787432
# 4             -1.428602           -0.078755           0.490084
#
#    temperatura_processo_c  abertura_valvula_pct  vibracao_bomba_mm_s  \
# 0                2.317030             -0.096176             0.971771
# 1                0.040508              0.290154             0.368680
# 2               -0.457051              0.282783            -0.124501
# 3                0.152319              0.381669             0.706862
# 4                2.317030              1.552943             1.271907
#
#    tempo_resposta_ms  ph_produto  densidade_produto_g_cm3  \
# 0          -1.574939    0.916810                 0.922717
# 1           1.087681    0.595436                 0.400630
# 2          -0.645298   -0.272276                -0.643545
# 3           2.324265   -0.432963                 1.705849
# 4          -0.657047   -0.465100                -1.198264
#
#    timestamp_2026-01-10 08:00:00  ...  operador_op_a  operador_op_b  \
# 0                           True  ...          False           True
# 1                          False  ...          False          False
# 2                          False  ...          False          False
# 3                          False  ...           True          False
# 4                          False  ...           True          False
#
#    operador_op_c  operador_op_d  modo_controle_automatico  \
# 0          False          False                      True
# 1           True          False                     False
# 2          False           True                     False
# 3          False          False                      True
# 4          False          False                      True
#
#    modo_controle_cascata  modo_controle_manual  status_valvula_intermitente  \
# 0                  False                 False                        False
# 1                   True                 False                        False
# 2                  False                  True                         True
# 3                  False                 False                         True
# 4                  False                 False                        False
#
#    status_valvula_normal  status_valvula_travada
# 0                   True                   False
# 1                   True                   False
# 2                  False                   False
# 3                  False                   False
# 4                   True                   False
#
# [5 rows x 203 columns]

# %% [markdown]
# ## 12. Consolidação com a variável-alvo

# %%
base_final_modelagem = X_final.copy()
base_final_modelagem[alvo] = y

print('Dimensão da base final completa:', base_final_modelagem.shape)
display(base_final_modelagem.head())
# Out:
# Dimensão da base final completa: (180, 204)
#    setpoint_vazao_l_min  vazao_medida_l_min  pressao_linha_bar  \
# 0              0.191198            0.639145          -0.856294
# 1              0.577176           -0.021791           1.750977
# 2              0.770573            0.716858           0.568444
# 3             -1.027936           -1.277268          -0.787432
# 4             -1.428602           -0.078755           0.490084
#
#    temperatura_processo_c  abertura_valvula_pct  vibracao_bomba_mm_s  \
# 0                2.317030             -0.096176             0.971771
# 1                0.040508              0.290154             0.368680
# 2               -0.457051              0.282783            -0.124501
# 3                0.152319              0.381669             0.706862
# 4                2.317030              1.552943             1.271907
#
#    tempo_resposta_ms  ph_produto  densidade_produto_g_cm3  \
# 0          -1.574939    0.916810                 0.922717
# 1           1.087681    0.595436                 0.400630
# 2          -0.645298   -0.272276                -0.643545
# 3           2.324265   -0.432963                 1.705849
# 4          -0.657047   -0.465100                -1.198264
#
#    timestamp_2026-01-10 08:00:00  ...  operador_op_b  operador_op_c  \
# 0                           True  ...           True          False
# 1                          False  ...          False           True
# 2                          False  ...          False          False
# 3                          False  ...          False          False
# 4                          False  ...          False          False
#
#    operador_op_d  modo_controle_automatico  modo_controle_cascata  \
# 0          False                      True                  False
# 1          False                     False                   True
# 2           True                     False                  False
# 3          False                      True                  False
# 4          False                      True                  False
#
#    modo_controle_manual  status_valvula_intermitente  status_valvula_normal  \
# 0                 False                        False                   True
# 1                 False                        False                   True
# 2                  True                         True                  False
# 3                 False                         True                  False
# 4                 False                        False                   True
#
#    status_valvula_travada  status_instrumentacao
# 0                   False                estavel
# 1                   False               inspecao
# 2                   False               inspecao
# 3                   False               inspecao
# 4                   False                estavel
#
# [5 rows x 204 columns]

# %% [markdown]
# ## 13. Verificações finais

# %%
display(base_final_modelagem.isnull().sum().rename_axis('coluna').reset_index(name='faltantes'))
display(base_final_modelagem.dtypes.rename_axis('coluna').reset_index(name='tipo'))
# Out:
#                           coluna  faltantes
# 0           setpoint_vazao_l_min          0
# 1             vazao_medida_l_min          0
# 2              pressao_linha_bar          0
# 3         temperatura_processo_c          0
# 4           abertura_valvula_pct          0
# ..                           ...        ...
# 199         modo_controle_manual          0
# 200  status_valvula_intermitente          0
# 201        status_valvula_normal          0
# 202       status_valvula_travada          0
# 203        status_instrumentacao          0
#
# [204 rows x 2 columns]
#                           coluna     tipo
# 0           setpoint_vazao_l_min  float64
# 1             vazao_medida_l_min  float64
# 2              pressao_linha_bar  float64
# 3         temperatura_processo_c  float64
# 4           abertura_valvula_pct  float64
# ..                           ...      ...
# 199         modo_controle_manual     bool
# 200  status_valvula_intermitente     bool
# 201        status_valvula_normal     bool
# 202       status_valvula_travada     bool
# 203        status_instrumentacao   object
#
# [204 rows x 2 columns]

# %% [markdown]
# ## 14. Exportação dos arquivos
#
# Salve os arquivos finais para uso nas próximas aulas.

# %%
X_final.to_csv('X_final_aula2.csv', index=False)
base_final_modelagem.to_csv('base_final_modelagem_aula2.csv', index=False)

print('Arquivos exportados com sucesso.')

# %% [markdown]
# ## 15. Fechamento da aula
#
# **Escreva, com suas palavras, o que foi feito nesta aula:**
# - separação entre atributos e alvo;
# - normalização e padronização;
# - codificação de variáveis categóricas;
# - preparação final da base para modelagem.

# %% [markdown]
# Nesta aula, preparamos a base para modelagem em 4 etapas: (1) separamos os dados em atributos (X) e alvo (y, a coluna status_instrumentacao); (2) escalonamos as variáveis numéricas por dois métodos — normalização (MinMaxScaler, intervalo [0,1]) e padronização (StandardScaler, média 0 e desvio 1); (3) codificamos as variáveis categóricas em binárias com one-hot encoding (pd.get_dummies); e (4) unimos tudo (numéricas padronizadas + categóricas codificadas + alvo) para gerar a base final, exportada em .csv e pronta para treinar modelos de machine learning.

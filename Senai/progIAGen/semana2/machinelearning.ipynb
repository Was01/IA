# %%
from sklearn.datasets import load_iris

# %%
data = load_iris()
print(data.data[:5])
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]]

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
X = data.data

# %%
y = data.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model = DecisionTreeClassifier()

# %%
model.fit(X_train, y_train)

print("Modelo com dados de treinamento inicializado.")
# Out:
# Modelo com dados de treinamento inicializado.

# %% [markdown]
# # **Realizando a predição no conjunto de teste**

# %%
y_pred = model.predict(X_test)

# %%
print("Primeiras previsões do modelo:")
print(y_pred[:10])
# Out:
# Primeiras previsões do modelo:
# [1 1 0 1 2 1 2 2 2 1]

# %%
print("Valores Reais: ")
print(y_test[:10])
# Out:
# Valores Reais:
# [1 1 0 1 2 1 1 2 2 1]

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
acc = accuracy_score(y_test, y_pred)

# %%
print(f"Acurácia do modelo: {acc:.2f}")
# Out:
# Acurácia do modelo: 0.97

# %% [markdown]
# ## Exercício Prático – Avaliação de Modelos de Classificação
#
# Objetivo: Desenvolver a autonomia na avaliação de modelos de Machine Learning utilizando a Matriz de Confusão (confusion_matrix) e o Relatório de Classificação (classification_report).

# %% [markdown]
# Exercício 1 – Realizando a predição
#
# Complete o código abaixo para realizar a predição do conjunto de teste.

# %%
# Realizando a predição no conjunto de teste

y_pred = model.predict(X_test)

# %% [markdown]
# Exercício 2 – Exibindo as previsões
#
# Complete o código.

# %%
print("Primeiras previsões do modelo:")
print(y_pred[:10])
# Out:
# Primeiras previsões do modelo:
# [1 1 0 1 2 1 2 2 2 1]

# %% [markdown]
# Exercício 3 – Exibindo os valores reais
#
# Complete o código.

# %%
print("Valores reais:")
print(y_test[:10])
# Out:
# Valores reais:
# [1 1 0 1 2 1 1 2 2 1]

# %% [markdown]
# Exercício 4 – Importando as métricas
#
# Complete a importação.

# %%
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report

# %% [markdown]
# Exercício 5 – Calculando a acurácia
#
# Complete o código.

# %%
acc = accuracy_score(y_test,y_pred)

# %%
print(f"Acurácia do modelo: {acc:.2f}")
# Out:
# Acurácia do modelo: 0.97

# %% [markdown]
# Exercício 6 – Gerando a Matriz de Confusão

# %%
matriz = confusion_matrix(y_test,y_pred)

print("Matriz de Confusão")
print(matriz)
# Out:
# Matriz de Confusão
# [[ 8  0  0]
#  [ 0 12  1]
#  [ 0  0  9]]

# %% [markdown]
# Obtendo o nome das classes

# %%
nomes_classes = data.target_names
print(nomes_classes)
# Out:
# ['setosa' 'versicolor' 'virginica']

# %% [markdown]
# Exercício 7 - Gerando o Classification Report
#
# Complete o código.

# %%
print(classification_report(y_test,y_pred,target_names=nomes_classes))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00         8
#   versicolor       1.00      0.92      0.96        13
#    virginica       0.90      1.00      0.95         9
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.97      0.97        30
# weighted avg       0.97      0.97      0.97        30

# %% [markdown]
# Sem consultar os exercícios anteriores, escreva o código necessário para:
#
#
#
# *   gerar as previsões do modelo;
# *   calcular a acurácia;
# *   gerar a matriz de confusão;
# *   exibir o relatório de classificação.

# %%
# Escreva seu código abaixo

#Gerando previsões do modelo

y_pred = model.predict(X_test)

#Calculando a acurácia

acc = accuracy_score(y_test,y_pred)

#Gerando a matriz de confusão

matriz = confusion_matrix(y_test,y_pred)

#Exibindo o relatório de classificação

print(classification_report(y_test,y_pred,target_names=nomes_classes))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00         8
#   versicolor       1.00      0.92      0.96        13
#    virginica       0.90      1.00      0.95         9
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.97      0.97        30
# weighted avg       0.97      0.97      0.97        30

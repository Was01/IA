# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df=pd.read_csv('dataset.csv')

print(df)
# Out:
#     temperatura   vibracao  pressao  tempo_operacao  falha
# 0     84.320000   3.260000    30.84           200.0      0
# 1     80.010000   3.010000    29.49           161.0      0
# 2     64.180000   3.620000    37.64           147.0      0
# 3     74.940000   3.070000    28.51           116.0      0
# 4     79.350000   4.680000    31.59           182.0      0
# 5     69.960000        NaN    29.35           191.0      0
# 6     76.860000   3.860000    37.23           128.0      0
# 7     75.760000   3.200000    24.91           154.0      0
# 8     75.030000   4.630000    30.19           187.0      0
# 9           NaN   2.840000    31.39            62.0      0
# 10    78.030000   4.090000    33.60           155.0      0
# 11    83.420000   3.180000    34.30            64.0      0
# 12    68.240000   2.650000    30.92           108.0      0
# 13   136.339617   8.003947    36.95           171.0      0
# 14    76.600000   2.780000    33.57           144.0      0
# ...

# %%
print(df.head())
# Out:
#    temperatura  vibracao  pressao  tempo_operacao  falha
# 0        84.32      3.26    30.84           200.0      0
# 1        80.01      3.01    29.49           161.0      0
# 2        64.18      3.62    37.64           147.0      0
# 3        74.94      3.07    28.51           116.0      0
# 4        79.35      4.68    31.59           182.0      0

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   temperatura     28 non-null     float64
#  1   vibracao        27 non-null     float64
#  2   pressao         31 non-null     float64
#  3   tempo_operacao  31 non-null     float64
#  4   falha           31 non-null     int64
# dtypes: float64(4), int64(1)
# memory usage: 1.3 KB
# None

# %%
print(df.describe())
# Out:
#        temperatura   vibracao    pressao  tempo_operacao      falha
# count    28.000000  27.000000  31.000000       31.000000  31.000000
# mean     79.829805   3.999013  31.568710      147.645161   0.258065
# std      18.353121   1.730971   5.536579       41.305809   0.444803
# min      61.160000   2.650000  21.340000       62.000000   0.000000
# 25%      69.960000   3.175000  28.930000      128.500000   0.000000
# 50%      76.275000   3.620000  31.390000      147.000000   0.000000
# 75%      80.725000   4.115000  34.135000      176.500000   0.500000
# max     142.954931  10.999410  44.340000      258.000000   1.000000

# %%
print(df.isnull().sum())
# Out:
# temperatura       3
# vibracao          4
# pressao           0
# tempo_operacao    0
# falha             0
# dtype: int64

# %%
print(df.fillna(df.mean()))
# Out:
#     temperatura   vibracao  pressao  tempo_operacao  falha
# 0     84.320000   3.260000    30.84           200.0      0
# 1     80.010000   3.010000    29.49           161.0      0
# 2     64.180000   3.620000    37.64           147.0      0
# 3     74.940000   3.070000    28.51           116.0      0
# 4     79.350000   4.680000    31.59           182.0      0
# 5     69.960000   3.999013    29.35           191.0      0
# 6     76.860000   3.860000    37.23           128.0      0
# 7     75.760000   3.200000    24.91           154.0      0
# 8     75.030000   4.630000    30.19           187.0      0
# 9     79.829805   2.840000    31.39            62.0      0
# 10    78.030000   4.090000    33.60           155.0      0
# 11    83.420000   3.180000    34.30            64.0      0
# 12    68.240000   2.650000    30.92           108.0      0
# 13   136.339617   8.003947    36.95           171.0      0
# 14    76.600000   2.780000    33.57           144.0      0
# ...

# %%
print(df.dropna())
# Out:
#     temperatura   vibracao  pressao  tempo_operacao  falha
# 0     84.320000   3.260000    30.84           200.0      0
# 1     80.010000   3.010000    29.49           161.0      0
# 2     64.180000   3.620000    37.64           147.0      0
# 3     74.940000   3.070000    28.51           116.0      0
# 4     79.350000   4.680000    31.59           182.0      0
# 6     76.860000   3.860000    37.23           128.0      0
# 7     75.760000   3.200000    24.91           154.0      0
# 8     75.030000   4.630000    30.19           187.0      0
# 10    78.030000   4.090000    33.60           155.0      0
# 11    83.420000   3.180000    34.30            64.0      0
# 12    68.240000   2.650000    30.92           108.0      0
# 13   136.339617   8.003947    36.95           171.0      0
# 14    76.600000   2.780000    33.57           144.0      0
# 15   142.954931  10.999410    44.34           132.0      1
# 16    67.040000   3.190000    24.46           137.0      0
# ...

# %%
print(df[['temperatura', 'vibracao']])
# Out:
#     temperatura   vibracao
# 0     84.320000   3.260000
# 1     80.010000   3.010000
# 2     64.180000   3.620000
# 3     74.940000   3.070000
# 4     79.350000   4.680000
# 5     69.960000        NaN
# 6     76.860000   3.860000
# 7     75.760000   3.200000
# 8     75.030000   4.630000
# 9           NaN   2.840000
# 10    78.030000   4.090000
# 11    83.420000   3.180000
# 12    68.240000   2.650000
# 13   136.339617   8.003947
# 14    76.600000   2.780000
# 15   142.954931  10.999410
# 16    67.040000   3.190000
# 17    75.950000   3.780000
# 18    85.390000   4.010000
# 19    67.440000   3.370000
# 20    61.160000        NaN
# 21    62.800000   3.760000
# 22    76.860000   3.010000
# 23    91.690000   4.140000
# 24    82.870000   4.260000
# 25          NaN   3.680000
# 26    75.690000        NaN
# 27          NaN   4.330000
# 28    73.100000   3.400000
# 29    79.290000   3.170000
# 30    69.960000        NaN

# %%
df1=df.drop('vibracao',axis=1)
print(df1)
# Out:
#     temperatura  pressao  tempo_operacao  falha
# 0     84.320000    30.84           200.0      0
# 1     80.010000    29.49           161.0      0
# 2     64.180000    37.64           147.0      0
# 3     74.940000    28.51           116.0      0
# 4     79.350000    31.59           182.0      0
# 5     69.960000    29.35           191.0      0
# 6     76.860000    37.23           128.0      0
# 7     75.760000    24.91           154.0      0
# 8     75.030000    30.19           187.0      0
# 9           NaN    31.39            62.0      0
# 10    78.030000    33.60           155.0      0
# 11    83.420000    34.30            64.0      0
# 12    68.240000    30.92           108.0      0
# 13   136.339617    36.95           171.0      0
# 14    76.600000    33.57           144.0      0
# 15   142.954931    44.34           132.0      1
# 16    67.040000    24.46           137.0      0
# 17    75.950000    35.10           188.0      0
# 18    85.390000    26.77           182.0      1
# ...

# %%
print(df.iloc[4])
# Out:
# temperatura        79.35
# vibracao            4.68
# pressao            31.59
# tempo_operacao    182.00
# falha               0.00
# Name: 4, dtype: float64

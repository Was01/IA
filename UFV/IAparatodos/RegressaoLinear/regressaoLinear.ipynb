# %%
## Regressao Linear

# %%
from matplotlib import pyplot as plt
import pandas as pd
import pylab as pl
import numpy as np
from sklearn import linear_model
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split
from math import sqrt

# %%
df=pd.read_csv('homeprices.csv')
df.head()
# Out:
#    area   price
# 0   100  250000
# 1   120  300000
# 2   150  450000
# 3   200  600000
# 4   250  800000

# %%
#Declarando o objeto

reg=linear_model.LinearRegression()

# Treinando o modelo

reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
a=reg.coef_[0]
b=reg.intercept_
print(a,b)
# Out:
# 11157.836382355272 -1454191.4152213517

# %%
plt.scatter(df.area,df.price,color='red',marker='o')
plt.plot(df.area,a*df.area+b,color='blue')
plt.xlabel('area')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

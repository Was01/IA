# %%
from PIL import Image, ImageFilter

# %%
img=Image.open('/content/bandeira.jpg')
novo_tamanho = (600, 600)  # (largura, altura) em pixels
img = img.resize(novo_tamanho)
display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=600x600>

# %%
r=15
filtered=img.filter(ImageFilter.BoxBlur(r))
display(filtered)
# Out:
# <PIL.Image.Image image mode=RGB size=600x600>

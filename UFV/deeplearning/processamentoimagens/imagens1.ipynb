# %%
# !pip install Pillow

# %%
from PIL import Image

# %%
image=Image.open('/content/massimiliano-morosinotto-FNulsVaXHLE-unsplash.jpg')

# %%
img_pequena = image.resize((400, 400))
display(img_pequena)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400>

# %%
print(image.getpixel((500,500)))
# Out:
# (70, 97, 26)

# %%
from PIL import Image
cor = Image.new("RGB", (100, 100), (70, 97, 26))
display(cor)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

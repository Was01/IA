# %%
from PIL import Image, ImageFilter

# %%
img=Image.open('/content/natureza.jpg')
novo_tamanho = (800, 800)  # (largura, altura) em pixels
img = img.resize(novo_tamanho)
display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=800x800>

# %%
filtro=img.filter(ImageFilter.CONTOUR)
filtro
# Out:
# <PIL.Image.Image image mode=RGB size=800x800>

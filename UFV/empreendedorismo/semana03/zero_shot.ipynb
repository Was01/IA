# %%
from google import genai
from google.colab import userdata

api_key = userdata.get('Gemini_API_Key')
client = genai.Client(api_key=api_key)

# %%
# Função auxiliar para fazer chamadas à API do Gemini
def obter_resposta_llm(texto_prompt, modelo="gemini-3.6-flash"):
    if not client:
        return "Erro: O cliente da API não foi inicializado."

    try:
        resposta = client.models.generate_content(
            model=modelo,
            contents=texto_prompt,
        )
        return resposta.text
    except Exception as e:
        return f"Erro na comunicação com a API do Gemini: {e}"

# %%
prompt = """Crie um problema de equação de 2º grau com aplicação em economia, e em seguida, resolva-o."
"""

# %%
if client:
    solucao = obter_resposta_llm(prompt)
    print(f"Problema/Solução: {solucao}")
# Out:
# Problema/Solução: Aqui está um problema contextualizado na área de economia (gestão financeira e produção) envolvendo uma equação do 2º grau, seguido de sua resolução detalhada.
#
# ---
#
# ### **Enunciado do Problema**
#
# Uma startup que produz luminárias artesanais de LED analisou seus custos e receitas e determinou que o seu **Lucro Mensal ($L$)**, em reais, em função da quantidade **$x$** de luminárias produzidas e vendidas no mês, é dado pela função quadrática:
#
# $$L(x) = -2x^2 + 100x - 600$$
#
# O diretor financeiro da empresa estipulou uma meta de obter um **lucro mensal de R$ 600,00**.
#
# 1. **Quantas luminárias a empresa deve produzir e vender no mês para atingir exatamente a meta de lucro de R$ 600,00?**
# 2. **Qual é a interpretação econômica para o fato de existirem duas soluções possíveis para este problema?**
#
# ---
#
# ### **Resolução Passo a Passo**
#
# #### **Parte 1: Encontrar a quantidade de luminárias ($x$)**
#
# **Passo 1: Igualar a função de lucro ao valor desejado.**
# Queremos que $L(x) = 600$. Substituindo na função:
# $$-2x^2 + 100x - 600 = 600$$
#
# **Passo 2: Organizar a equação na forma padrão ($ax^2 + bx + c = 0$).**
# Subtraímos $600$ de ambos os lados:
# $$-2x^2 + 100x - 600 - 600 = 0$$
# $$-2x^2 + 100x - 1200 = 0$$
#
# **Passo 3: Simplificar a equação (opcional, mas facilita os cálculos).**
# Podemos dividir todos os termos por $-2$:
# $$x^2 - 50x + 600 = 0$$
#
# Aqui temos:
# * $a = 1$
# * $b = -50$
# * $c = 600$
#
# **Passo 4: Aplicar a Fórmula de Bhaskara.**
# Primeiro, calculamos o discriminante ($\Delta$):
# $$\Delta = b^2 - 4ac$$
# $$\Delta = (-50)^2 - 4 \cdot 1 \cdot 600$$
# $$\Delta = 2500 - 2400$$
# $$\Delta = 100$$
#
# Agora, encontramos as raízes para $x$:
# $$x = \frac{-b \pm \sqrt{\Delta}}{2a}$$
# $$x = \frac{-(-50) \pm \sqrt{100}}{2 \cdot 1}$$
# $$x = \frac{50 \pm 10}{2}$$
#
# Calculando as duas opções:
# * $x_1 = \frac{50 + 10}{2} = \frac{60}{2} = 30$
# * $x_2 = \frac{50 - 10}{2} = \frac{40}{2} = 20$
#
# ---
#
# ### **Resposta e Análise Econômica**
#
# 1. **Resposta Numérica:**
# A empresa pode atingir a meta de R$ 600,00 de lucro produzindo e vendendo **20 unidades** ou **30 unidades** no mês.
#
# 2. **Interpretação Econômica:**
# * **Produzindo 20 unidades:** A empresa atinge o lucro de R$ 600,00 com custos de produção menores, mas com uma receita total menor.
# * **Produzindo 30 unidades:** A empresa vende mais, gerando maior receita bruta, porém os custos operacionais (como matéria-prima, horas extras de funcionários ou desgaste de maquinário) aumentam no mesmo ritmo, fazendo com que o lucro líquido retorne ao patamar de R$ 600,00.
# *(Nota: O lucro máximo dessa empresa ocorreria no vértice da parábola, ou seja, vendendo exatamente 25 unidades, gerando um lucro máximo de R$ 650,00).*
